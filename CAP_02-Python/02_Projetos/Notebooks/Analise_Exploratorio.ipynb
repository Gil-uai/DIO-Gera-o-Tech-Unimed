# %% [markdown]
# # Analise de Dados Adventure Works - 💻

# %% [markdown]
# **Projeto 3/3 - Capitulo 03**
#
# *Análise de dados com Python e Pandas | Bootcampo Geração tech Unimed-BH*
#
# Neste projeto temos a base de dados Adventure Works com dados de vendas de equipamento de informatica onde iremos fazer uma análise exploratorio destes dados como forma de praticar a biblioteca Pandas.

# %% [markdown]
# Sobre o codigo utilizado para desenvolvimento deste projeto, o mesmo esta com comentários de forma a deixar claro o implementação e também como forma didatica de fixação do conteudo em estudo.

# %%
#Importando as bibliotecas que serão utilizadas no projeto
import pandas as pand
import matplotlib.pyplot as plotar
plotar.style.use ("dark_background") # definindo o stylo dos graficos que iremos utilizar ao longo da análise

# %%
# Realizando o carregamento da base de dados
from google.colab import files
arquivo = files.upload()
# Out:
#      <input type="file" id="files-6d9aebe0-a8cf-4799-a682-aafcac1bebf5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6d9aebe0-a8cf-4799-a682-aafcac1bebf5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Criando dataframe
base = pand.read_excel("AdventureWorks.xlsx")

# %%
# Verificação rapida do carregamento dos dados
base.head (3)
# Out:
#   Data Venda Data Envio  ID Loja  ID Produto  ID Cliente       No. Venda  \
# 0 2008-05-09 2008-05-29      199         384       18839  200805093CS607
# 1 2008-05-12 2008-05-17      306         384       19051  200805123CS567
# 2 2008-05-14 2008-05-20      306         384       19052  200805143CS576
#
#    Custo Unitário  Preço Unitário  Quantidade  Valor Desconto  Valor Venda  \
# 0          348.58           758.0           6             0.0       4548.0
# 1          348.58           758.0           6             0.0       4548.0
# 2          348.58           758.0           6             0.0       4548.0
#
#                                  Produto       Fabricante            Marca  \
# 0  Adventure Works Laptop15.4W M1548 Red  Adventure Works  Adventure Works
# 1  Adventure Works Laptop15.4W M1548 Red  Adventure Works  Adventure Works
# 2  Adventure Works Laptop15.4W M1548 Red  Adventure Works  Adventure Works
#
#     Classe  Cor
# 0  Regular  Red
# 1  Regular  Red
# ...

# %%
# Verificando o tamanho a planilha (linhas, colunas)
base.shape
# Out:
# (904, 16)

# %%
# Verificando o tipo de dado de cada coluna
base.dtypes
# Out:
# Data Venda        datetime64[ns]
# Data Envio        datetime64[ns]
# ID Loja                    int64
# ID Produto                 int64
# ID Cliente                 int64
# No. Venda                 object
# Custo Unitário           float64
# Preço Unitário           float64
# Quantidade                 int64
# Valor Desconto           float64
# Valor Venda              float64
# Produto                   object
# Fabricante                object
# Marca                     object
# Classe                    object
# Cor                       object
# dtype: object

# %%
# Analisar qual a receita total
base["Valor Venda"].sum() # Tomamos como premissa que a coluna #Valor Venda" é o valor unitario multiplicado pela quantidade
# Out:
# 5984606.1426

# %%
# Analisar a quantidade total de itens vendidos
base["Quantidade"].sum()
# Out:
# 56907

# %%
base["Quantidade"].count()
# Out:
# 904

# %%
# Encontrando a média de itens vendidos por venda de forma indireta
base["Quantidade"].sum() / base["Quantidade"].count()
# Out:
# 62.950221238938056

# %%
# Econtrando a média de itens vendidos por venda atraves de metodo mean
base["Quantidade"].mean()
# Out:
# 62.950221238938056

# %%
# Analisar qual o custo de venda total
base["Custo"] = base["Custo Unitário"].mul(base["Quantidade"]) # criando a coluna Custo de cada venda multiplicando o total vendido pelo custo unitario

# %%
base.head()
# Out:
#   Data Venda Data Envio  ID Loja  ID Produto  ID Cliente       No. Venda  \
# 0 2008-05-09 2008-05-29      199         384       18839  200805093CS607
# 1 2008-05-12 2008-05-17      306         384       19051  200805123CS567
# 2 2008-05-14 2008-05-20      306         384       19052  200805143CS576
# 3 2008-05-21 2008-05-27      306         384       19052  200805213CS576
# 4 2008-06-20 2008-06-27      306         384       19053  200806203CS586
#
#    Custo Unitário  Preço Unitário  Quantidade  Valor Desconto  Valor Venda  \
# 0          348.58           758.0           6             0.0       4548.0
# 1          348.58           758.0           6             0.0       4548.0
# 2          348.58           758.0           6             0.0       4548.0
# 3          348.58           758.0           6             0.0       4548.0
# 4          348.58           758.0           6             0.0       4548.0
#
# ...

# %%
base.sample ()
# Out:
#     Data Venda Data Envio  ID Loja  ID Produto  ID Cliente       No. Venda  \
# 531 2008-10-01 2008-10-12      306        1202       19057  200810014CS636
#
#      Custo Unitário  Preço Unitário  Quantidade  Valor Desconto  Valor Venda  \
# 531          330.66           998.0           4           798.4       3193.6
#
#                                         Produto      Fabricante     Marca  \
# 531  Fabrikam Trendsetter 1/3'' 8.5mm X200 Grey  Fabrikam, Inc.  Fabrikam
#
#       Classe   Cor    Custo
# 531  Regular  Grey  1322.64

# %%
#Verificando custo total
base["Custo"].sum()
# Out:
# 2486783.05

# %%
# Criando uma coluna com o lucro por venda
base["Lucro"] = base["Valor Venda"] - base["Custo"]

# %%
base.sample (3)
# Out:
#     Data Venda Data Envio  ID Loja  ID Produto  ID Cliente       No. Venda  \
# 888 2008-09-26 2008-10-04      199        1155       18874  200809264CS695
# 225 2009-07-16 2009-07-29      307         384       19129  200907163CS719
# 139 2008-10-30 2008-11-11      307         366       19108  200810303CS648
#
#      Custo Unitário  Preço Unitário  Quantidade  Valor Desconto  Valor Venda  \
# 888          324.69           980.0           6           588.0       5292.0
# 225          348.58           758.0           8             0.0       6064.0
# 139          348.58           758.0           6             0.0       4548.0
#
#                                         Produto       Fabricante  \
# 888  Fabrikam Trendsetter 2/3'' 17mm X100 Black   Fabrikam, Inc.
# 225       Adventure Works Laptop15.4W M1548 Red  Adventure Works
# 139     Adventure Works Laptop15.4W M1548 Black  Adventure Works
#
#                Marca   Classe    Cor    Custo    Lucro
# ...

# %%
# Verificando lucro total
base["Lucro"].sum()
# Out:
# 3497823.0926

# %%
# Criando coluna com numero de dias para envio do produto
base["Tempo Envio"] = (base["Data Envio"] - base["Data Venda"])

# %%
base.sample (3)
# Out:
#     Data Venda Data Envio  ID Loja  ID Produto  ID Cliente       No. Venda  \
# 578 2009-06-17 2009-06-27      307        1178       19126  200906174CS716
# 693 2008-11-20 2008-12-03      307        2496       19109  200811205CS655
# 492 2009-11-25 2009-11-29      199        1155       19020  200911254CS935
#
#      Custo Unitário  Preço Unitário  Quantidade  Valor Desconto  Valor Venda  \
# 578          330.66          998.00           8         798.400     7185.600
# 693            5.09            9.99         156         233.766     1324.674
# 492          324.69          980.00          24        4704.000    18816.000
#
#                                              Produto      Fabricante  \
# 578      Fabrikam Trendsetter 1/3'' 8.5mm X200 White  Fabrikam, Inc.
# 693  Headphone Adapter for Contoso Phone E130 Silver    Contoso, Ltd
# 492       Fabrikam Trendsetter 2/3'' 17mm X100 Black  Fabrikam, Inc.
#
#         Marca   Classe     Cor    Custo      Lucro Tempo Envio
# ...

# %%
# Alterar a coluna Tempo Envio eliminando a String "days"
# Ao criar a coluna "Tempo Envio" foi adicionada string "days" no final com isso não conseguimos fazer calculo com a mesma
base["Tempo Envio"] = (base["Data Envio"] - base["Data Venda"]).dt.days # agora acrescentamos para considerar somente o dia

# %%
base.head(1)
# Out:
#   Data Venda Data Envio  ID Loja  ID Produto  ID Cliente       No. Venda  \
# 0 2008-05-09 2008-05-29      199         384       18839  200805093CS607
#
#    Custo Unitário  Preço Unitário  Quantidade  Valor Desconto  Valor Venda  \
# 0          348.58           758.0           6             0.0       4548.0
#
#                                  Produto       Fabricante            Marca  \
# 0  Adventure Works Laptop15.4W M1548 Red  Adventure Works  Adventure Works
#
#     Classe  Cor    Custo    Lucro  Tempo Envio
# 0  Regular  Red  2091.48  2456.52           20

# %%
# Conferindo o tipo de dado da coluna "Tempo Envio"
base["Tempo Envio"].dtypes
# Out:
# dtype('int64')

# %%
# Verificando a média do tempo de envio por marca
base.groupby("Marca")["Tempo Envio"].mean()
# Out:
# Marca
# Adventure Works    8.663866
# Contoso            8.470930
# Fabrikam           8.510121
# Name: Tempo Envio, dtype: float64

# %% [markdown]
# ### Verificar existência de Valores nulos

# %%
# Vrrificando quantidade de itens faltantes por coluna
base.isnull().sum()
# Out:
# Data Venda        0
# Data Envio        0
# ID Loja           0
# ID Produto        0
# ID Cliente        0
# No. Venda         0
# Custo Unitário    0
# Preço Unitário    0
# Quantidade        0
# Valor Desconto    0
# Valor Venda       0
# Produto           0
# Fabricante        0
# Marca             0
# Classe            0
# Cor               0
# Custo             0
# Lucro             0
# Tempo Envio       0
# dtype: int64

# %% [markdown]
# ### Agrupar Valores

# %%
# Verificando o lucro por ano e por marca
base.groupby([base["Data Venda"].dt.year, "Marca"])["Lucro"].sum()
# Out:
# Data Venda  Marca
# 2008        Adventure Works             306,641.16
#             Contoso                      56,416.00
#             Fabrikam                  1,557,020.55
# 2009        Adventure Works             405,395.08
#             Contoso                     138,258.95
#             Fabrikam                  1,034,091.35
# Name: Lucro, dtype: float64

# %%
# Alterando a forma de exibição
pand.options.display.float_format = '{:20,.2f}'.format # formata os numero float para 2 casas decimais

# %%
# Resentando o index e transformando os retornos em tabela
lucro_ano = base.groupby([base["Data Venda"].dt.year, "Marca"])["Lucro"].sum().reset_index()

# %%
lucro_ano
# Out:
#    Data Venda            Marca                Lucro
# 0        2008  Adventure Works           306,641.16
# 1        2008          Contoso            56,416.00
# 2        2008         Fabrikam         1,557,020.55
# 3        2009  Adventure Works           405,395.08
# 4        2009          Contoso           138,258.95
# 5        2009         Fabrikam         1,034,091.35

# %%
# Verificando a quantidade total vendida por produto
base.groupby("Produto")["Quantidade"].sum().sort_values(ascending=False) # acrescentado sort para colocar em ordem crecente
# Out:
# Produto
# Headphone Adapter for Contoso Phone E130 Silver    25232
# Headphone Adapter for Contoso Phone E130 White     25008
# Adventure Works Laptop15.4W M1548 Black             1089
# Fabrikam Trendsetter 2/3'' 17mm X100 Grey           1087
# Adventure Works Laptop15.4W M1548 Red               1047
# Fabrikam Trendsetter 2/3'' 17mm X100 Black           926
# Fabrikam Trendsetter 1/3'' 8.5mm X200 Black          884
# Fabrikam Trendsetter 1/3'' 8.5mm X200 Grey           845
# Fabrikam Trendsetter 1/3'' 8.5mm X200 White          789
# Name: Quantidade, dtype: int64

# %% [markdown]
# ### Realizar análises com gráficos

# %%
# Exibir grafico com total de produtos vendidos por marca
base.groupby("Produto")["Quantidade"].sum().sort_values(ascending=True).plot.barh(title = "Vendas por Produto");

# %%
# Exibir grafico de lucro por ano
base.groupby(base["Data Venda"].dt.year)["Lucro"].sum().plot.bar(title = "Lucro x ano")
plotar.xlabel("Ano")
plotar.ylabel("Lucro");

# %%
# Analisando somente as vendas de 2009
# agrupar somente as vendas de 2009
base_2009 = base[base["Data Venda"].dt.year == 2009]

# %%
base_2009.head(1)
# Out:
#    Data Venda Data Envio  ID Loja  ID Produto  ID Cliente       No. Venda  \
# 11 2009-05-02 2009-05-14      199         384       18938  200905023CS847
#
#          Custo Unitário       Preço Unitário  Quantidade       Valor Desconto  \
# 11               348.58               758.00           6                 0.00
#
#             Valor Venda                                Produto  \
# 11             4,548.00  Adventure Works Laptop15.4W M1548 Red
#
#          Fabricante            Marca   Classe  Cor                Custo  \
# 11  Adventure Works  Adventure Works  Regular  Red             2,091.48
#
#                   Lucro  Tempo Envio
# 11             2,456.52           12

# %%
# Verificando na nova base temos somente dados de 2009
base_2009.sample (5)
# Out:
#     Data Venda Data Envio  ID Loja  ID Produto  ID Cliente       No. Venda  \
# 897 2009-06-12 2009-06-22      307        1226       19126  200906124CS716
# 346 2009-01-16 2009-01-23      307        1202       19113  200901164CS680
# 831 2009-12-15 2009-12-19      199        1203       19030  200912154CS946
# 528 2009-10-22 2009-10-31      306        1155       19075  200910224CS765
# 399 2009-01-11 2009-01-18      307        1178       19113  200901114CS680
#
#           Custo Unitário       Preço Unitário  Quantidade  \
# 897               330.99               999.00           6
# 346               330.66               998.00          17
# 831               324.69               980.00           6
# 528               324.69               980.00           4
# 399               330.66               998.00          13
#
#           Valor Desconto          Valor Venda  \
# 897               599.40             5,394.60
# 346             2,544.90            14,421.10
# ...

# %%
# Exigir grafico do lucro por mês no ano de 2009
base_2009.groupby(base_2009["Data Venda"].dt.month)["Lucro"].sum().plot(title = "Lucro x Mês");
plotar.xlabel ("Mês")
plotar.ylabel ("Lucro");

# %%
# Exibir grafico de lucro por marca no ano de 2009
base_2009.groupby(base_2009["Marca"])["Lucro"].sum().plot.bar(title = "Lucro x Marca")
plotar.xlabel ("Marca")
plotar.ylabel ("Lucro");
plotar.xticks(rotation='horizontal');

# %%
# Exibir grafico de lucro por classe no ano de 2009
base_2009.groupby(base_2009["Classe"])["Lucro"].sum().plot.bar(title = "Lucro x Marca")
plotar.xlabel ("Classe")
plotar.ylabel ("Lucro");
plotar.xticks(rotation='horizontal');

# %%
# Exibir estatisticas gerais do tempo de envio
base["Tempo Envio"].describe()
# Out:
# count                 904.00
# mean                    8.54
# std                     3.06
# min                     4.00
# 25%                     6.00
# 50%                     9.00
# 75%                    11.00
# max                    20.00
# Name: Tempo Envio, dtype: float64

# %%
# Exibir grafico tipo boxplot para o tempo de envio
plotar.style.use ("classic") # Alterado Stilo para melhorar visualização do boxplot
plotar.boxplot(base["Tempo Envio"]);

# %%
#exibir histrograma do Tempo de envio
plotar.style.use ("dark_background")
plotar.hist(base["Tempo Envio"]);
plotar.title("Histograma tempo de envio");

# %%
# Salvando uma nova versão da base de dados
base.to_csv("Base_nova.csv", index=False)

# %%
base.head()
# Out:
#   Data Venda Data Envio  ID Loja  ID Produto  ID Cliente       No. Venda  \
# 0 2008-05-09 2008-05-29      199         384       18839  200805093CS607
# 1 2008-05-12 2008-05-17      306         384       19051  200805123CS567
# 2 2008-05-14 2008-05-20      306         384       19052  200805143CS576
# 3 2008-05-21 2008-05-27      306         384       19052  200805213CS576
# 4 2008-06-20 2008-06-27      306         384       19053  200806203CS586
#
#         Custo Unitário       Preço Unitário  Quantidade       Valor Desconto  \
# 0               348.58               758.00           6                 0.00
# 1               348.58               758.00           6                 0.00
# 2               348.58               758.00           6                 0.00
# 3               348.58               758.00           6                 0.00
# 4               348.58               758.00           6                 0.00
#
# ...

# %%
# Exibir de forma grafica a quantidade de vendas por cor
base.groupby("Cor")["Quantidade"].sum().sort_values (ascending=False).plot.bar(title = "Quantidade venda por Cor");
plotar.xlabel ("Cor")
plotar.ylabel ("Qtde");
